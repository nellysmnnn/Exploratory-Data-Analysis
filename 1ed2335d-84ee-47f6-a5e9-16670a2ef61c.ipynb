# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Нелли, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провела
#     хорошую работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# Нелли, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!
#
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание, рекомендация.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделала огромную работу :)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект  лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Research on Apartment Sales Advertisements
# You have access to data from Yandex Realty—an archive of housing sale advertisements in Saint Petersburg and neighboring settlements over several years. Your task is to learn how to determine the market value of real estate properties. To do this, conduct an exploratory data analysis (EDA) and identify the parameters that influence property prices. This will make it possible to build an automated system designed to track anomalies and fraudulent activity.
#
# Two types of data are available for each apartment for sale. The first type is entered manually by the user, while the second is generated automatically based on cartographic data. For example, the distance to the city center, the airport, and other locations is automatically retrieved from geo-services. The number of parks and bodies of water is also populated without user intervention.

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Импорт всех библиотек лучше делать в одной отдельной ячейке, чтобы при необходимости можно было ее перезапустить без влияния на другой код и перезаписи датафрейма. </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %%
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
# ...

# %%
data.head(5)

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Чтобы перед графиком не выводился длинный список с параметрами, можно просто добавить строку `plt.show()` после строки построения графика.  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **<span style="color: green;">Some columns contain anomalously large values atypical of residential real estate, such as property area. These outliers require further processing.
# </span>**

# %%
data.isnull().sum()

# %%
data.info()

# %% [markdown]
# **<span style="color: green;">Missing values and data types in certain columns will also need to be addressed.
# </span>**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# При знакомстве с данными еще обязательно нужно изучить общую информацию о них с помощью метода `info()`
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# ### Выполните предобработку данных
#
# **2.1 Заполнение пропущенных значений**

# %% [markdown]
# Ceiling height is an optional field in the listing, which could lead to missing values. Missing values in the ceiling_height column will be replaced with the column's median value. The median is well-suited for quantitative data and is robust against outliers.

# %%
data['ceiling_height'].fillna(data['ceiling_height'].median(), inplace=True)
#data['floors_total'].fillna(data['floors_total'].median(), inplace=True)
#data['living_area'].fillna(data['living_area'].median(), inplace=True)
#data['kitchen_area'].fillna(data['kitchen_area'].median(), inplace=True)

# %% [markdown]
# To fill in the missing values in living_area and kitchen_area, we will calculate the average ratios of these areas to total_area. Then, for rows with missing values, we will substitute the product of the total area and the corresponding ratio.

# %%
living_coef = (data['living_area'] / data['total_area']).mean(skipna=True)
kitchen_coef = (data['kitchen_area'] / data['total_area']).mean(skipna=True)

living_filled = data['total_area'] * living_coef
kitchen_filled = data['total_area'] * kitchen_coef

data['living_area'] = data['living_area'].fillna(living_filled)
data['kitchen_area'] = data['kitchen_area'].fillna(kitchen_filled)

# %%
incorrect_lines = data[data['total_area'] < data['living_area'] + data['kitchen_area']].shape[0]
incorrect_lines

# %%
incorrect_lines / data.shape[0]

# %%
data = data.query('(living_area + kitchen_area < total_area)')

# %%
incorrect_lines_2 = data[data['total_area'] < data['living_area'] + data['kitchen_area']].shape[0]
incorrect_lines_2

# %% [markdown]
# The proportion of missing values in the floors_total column is also negligible, so we will drop them.

# %%
data['floors_total'].isna().sum()/data.shape[0]

# %%
data = data.dropna(subset=['floors_total'])

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Получили 741 квартиру, у которых сумма жилой площади и площади кухни больше общей. Такое заполнение пропусков в площадях некорректно.
#
# Пропуски можно заполнить так: сначала вычисляем среднее отношение жилой площади к общей, это будет наш коэффициент жилой площади. Далее в строках с пропусками умножаем общую площадь на этот коэффициент, получая жилую площадь.
#
# Подобным образом можно заполнить пропуски и в столбце с площадью кухни.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# При таком заполнении пропусков в количестве этажей могут появиться квартиры, у которых этаж расположения будет выше общего количества этажей в доме. Строк с пропусками в этом столбце не так много и их можно просто исключить или оставить как есть.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# Missing values in the parks_around3000 and ponds_around3000 columns will be replaced with 0, as there are most likely no parks or ponds within a 3,000 km radius.

# %%
columns_to_fill = ['parks_around3000', 'ponds_around3000']

for column in columns_to_fill:
    data[column] = data[column].fillna(0)

# %%
data.isnull().sum()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Обрати внимание, что locality_name это не район города, а отдельный населенный пункт. Обязательно ли рядом с каждой квартирой должен быть парк и пруд?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# Missing values in the balcony column will be replaced with 0, as they most likely indicate the absence of a balcony.

# %%
data['balcony'].fillna(0, inplace=True)

# %% [markdown]
# Missing values in the is_apartment column will be replaced with the boolean value False, as the absence of a value likely indicates that the property is not an apartment.

# %%
data['is_apartment'].fillna(False, inplace=True)

# %% [markdown]
# The locality_name column contains important information, yet the proportion of rows with missing values is only 0.0021 (0.2%).

# %%
data['locality_name'].isna().sum()/data.shape[0]

# %% [markdown]
# Rows with missing values in the locality_name column will be dropped. Given that the proportion of such rows is only 0.0021 (0.2%), removing them will not lead to significant data distortion.

# %%
data = data.dropna(subset=['locality_name'])

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Согласен  </div>

# %% [markdown]
# Missing values in the airports_nearest, cityCenters_nearest, pond_nearest, and park_nearest columns will be left as NaN, since it is unlikely that these values can be logically recovered, and filling them with any average value would introduce unwarranted anomalies.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Обрати внимание на то, что эти значения  получены автоматически на основе картографических данных. А если данные не получены, то скорее всего объекта рядом нет (пруды и парки) или до объекта слишком далеко и эту информацию нельзя получить (а значит она и не будет иметь значения при исследовании)
#
# А заполняя пропуски медианой, мы переносим квартиры и сажаем рядом парки и выкапываем пруды)) Это неправильно. Лучше в таком случае оставить пропуски как есть.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# Missing values in the days_exposition column will be left unchanged, as they may indicate that the listing is still active or that the omission was accidental. Replacing these values could distort the results of the analysis.

# %%
data.isnull().sum()

# %% [markdown]
# **2.2 Изменение типов данных**

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S', errors='coerce')

# %%
data['is_apartment'] = data['is_apartment'].astype(bool)

# %%
data['balcony'] = data['balcony'].astype(int)
data['floors_total'] = data['floors_total'].astype(int)
data['ponds_around3000'] = data['ponds_around3000'].astype(int)
data['parks_around3000'] = data['parks_around3000'].astype(int)

# %%
data.info()

# %% [markdown]
# **2.3 Устранение неявных дубликатов**

# %%
data['locality_name'].nunique()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Количество уникальных значений в столбце можно узнать с помощью метода `nunique()`  </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %%
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е') 
    .replace(
        ['поселок городского типа', 'деревня', 'городской посёлок'], 
        'поселок',  
        regex=True 
    )
)
data['locality_name'].unique()

# %%
data['locality_name'].nunique()

# %%
has_duplicates = data.duplicated().any()

if has_duplicates:
    print("There are explicit duplicates in the table.")
else:
    print("No explicit duplicates were found.")

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# А нет ли в таблице явных дубликатов строк?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %%
data['price_per_meter'] = (data['last_price'] / data['total_area']).round(2)

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday


data['month_exposition'] = data['first_day_exposition'].dt.month

data['year_exposition'] = data['first_day_exposition'].dt.year

# %%
def get_floor_type(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

data['floor_type'] = data.apply(get_floor_type, axis=1)

# %%
data['city_center_km'] = (data['cityCenters_nearest'] / 1000).round(0)

# %% [markdown]
# **<span style="color: green;">Data Preprocessing Summary</span>**
#
#
# - **Identified and handled missing values: some were filled (e.g., balconies replaced with 0), some calculated using average ratios (living area, kitchen), while others were left as structural/informative NaN values.**
#
# - **Adjusted data types for correct analysis: dates were converted to the datetime format, and numeric categories to int and float.**
#
# - **Standardized duplicated locality names into a uniform format.**
#
# - **Removed rows with anomalies (such as cases where the sum of component areas exceeds the total area) as well as full duplicates.**
#
# - **Engineered new features: price per square meter, day of the week, month, and year of publication, floor category, and distance to the city center.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После этапа предобработки нужно сделать краткий резюмирующий вывод о проделанной работе.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Дополнительные данные рассчитаны и добавлены верно! Можно приступать к исследованию🙂 </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# **<span style="color: blue;">Study of Property Parameters and Outlier Detection
# </span>**
#
# **A step-by-step visual analysis was used to identify anomalous values:**
#
# - Histograms were plotted to get a general overview of the feature distribution and initially spot outlying values.
#
# - Boxplots were created to determine the boundaries of normal values and the upper threshold point above which outliers may reside.
#
# - Histograms were plotted exclusively for values above the upper bound of the boxplot, which allowed for a closer inspection of the distribution's tail.
#
# - Outliers were determined manually based on visual analysis of the histogram: values that deviated significantly from the main bulk of the data were classified as anomalies.

# %% [markdown]
# **1. Living Area**

# %%
data['living_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(10, 250)

plt.title('Distribution of Living Area')
plt.xlabel('Area') 
plt.ylabel('Number of Listings')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Необходимо подписывать название для каждого графика и оси на нем. Есть [хорошая статья](https://devpractice.ru/matplotlib-lesson-3-3-text-elements/), которая подскажет как это правильно сделать). </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **<span style="color: green;">Гистограмма жилой площади демонстрирует асимметричное распределение с длинным правым хвостом, что может указывать на наличие выбросов. Основная масса значений сосредоточена в диапазоне от 20 до 100 м², что соответствует типичной жилой недвижимости.
# </span>**

# %%
# Определим верхнюю границу, построим дополнительную гистограмму выше нее,
# чтобы точнее выявить аномальные значения и при необходимости удалить их.
data['living_area'].plot(kind='box', showfliers=False)

# %%
data[data['living_area'] > 70]['living_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(100, 400)

plt.title('Распределение значений жилой площади выше верхней границы')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
# Выведим общую информацию о столбце
data['living_area'].describe()

# %% [markdown]
# После значения 200 м² распределение становится слишком разбросанным, что может свидетельствовать о выбросах. Поэтому ограничим значения жилой площади в диапазоне от 10 до 200 м² и создадим новую таблицу **filtered_data**, в которую будем добавлять очищенные столбцы.

# %%
filtered_data = data.query('10 < living_area <= 200')

# %% [markdown]
# **2. Общая площадь**

# %%
filtered_data['total_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(10, 250)

plt.title('Распределение значений общей площади')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# **<span style="color: green;">Гистограмма общей площади демонстрирует асимметричное распределение опять же с длинным правым хвостом, что может указывать на наличие выбросов.
# </span>**

# %%
filtered_data['total_area'].plot(kind='box', showfliers=False)

# %%
filtered_data['total_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(10, 150)

plt.title('Распределение значений общей площади выше верхней границы')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Из-за наличия больших значений графики получаются очень сжатыми и реальный диапазон значений очень сложно определить, можно рассмотреть его поближе, ограничив значения на оси с помощью `plt.xlim()`. Пример привел ниже</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %%
# код ревьюера


filtered_data['total_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(100, 500)

plt.title('Распределение значений общей площади')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
filtered_data['total_area'].describe()

# %% [markdown]
# Ограничиваем значения общей площади в диапазоне от 20 до 250 м².

# %%
filtered_data = data.query('20 < total_area <= 250')

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
#  - А почему мы отбрасываем только аномально высокие значения?
#
#  - В качестве дополнительного инструмента для анализа можно использовать `describe()`</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **3. Площадь кухни**

# %%
filtered_data['kitchen_area'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(0, 70)

plt.title('Распределение значений площади кухни')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# **<span style="color: green;">Гистограмма площади кухни демонстрирует распределение с пиком около 10 м², что характерно для среднестатистической кухни, и имеет правосторонний хвост с аномально большими значениями. Выбросы могут быть связаны как с элитными постройками, так и с ошибками при заполнении данных.
# </span>**

# %%
filtered_data['kitchen_area'].plot(kind='box', showfliers=False)

# %%
filtered_data['kitchen_area'].hist(bins = 100, figsize = (15, 7), color='#A7D2CB')
plt.xlim(20, 60)

plt.title('Распределение значений площади кухни выше верхней границы')
plt.xlabel('Площадь') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
filtered_data['kitchen_area'].describe()

# %% [markdown]
# Ограничиваем площадь кухни от 3 до 40 м².

# %%
filtered_data = filtered_data.query('3 < kitchen_area <= 40')

# %% [markdown]
# **4. Количество комнат**

# %%
filtered_data['rooms'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(12, 6),
    title='Распределение количества комнат')
plt.xlabel('Комнаты')
plt.ylabel('Количество объявлений')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Для дискретных переменных лучше использовать барплот</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **<span style="color: green;">Большинству квартир присвоено количество комнат от 1 до 3, что характерно для типичной недвижимости.
# </span>**

# %%
filtered_data['rooms'].plot(kind='box', showfliers=False)

# %%
filtered_data['rooms'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(12, 6),
    title='Распределение количества комнат выше верхней границы')
plt.xlim(5, 14)
plt.xlabel('Комнаты')
plt.ylabel('Количество объявлений')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
filtered_data['rooms'].describe()

# %% [markdown]
# Ограничиваем количество комнат в диапазоне от 1 до 6.

# %%
filtered_data=filtered_data.query('rooms < 7')

# %% [markdown]
# **5. Высота потолка**

# %%
filtered_data['ceiling_height'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(2, 5)

plt.title('Распределение значений высоты потолка')
plt.xlabel('Высота') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
filtered_data['ceiling_height'].plot(kind='box', showfliers=False)

# %% [markdown]
# **<span style="color: green;">Boxplot помогает визуально оценить средний диапазон значений высоты потолков — от 2,45 до 2,85 метров.
# </span>**

# %%
filtered_data['ceiling_height'].describe()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Можно ли сделать какие-либо выводы по такому "распределению" ? Визуализация должна быть информативной </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# Ограничиваем высоту потолков в диапазоне от 2.4 до 3.5 метров.

# %%
filtered_data = filtered_data.query('2.4 < ceiling_height < 3.5')

# %% [markdown]
# **6. Тип этажа**

# %%
filtered_data['floor_type'].hist(bins=15)

# %% [markdown]
# **<span style="color: green;"> Гистограмма явно показывает, что большая часть продаваемых квартир относится к категории 'другая', а не к 'первой' или 'последней'. Данные выглядят правдоподобно — категория 'другая' более широкая, и, следовательно, включает больше квартир.
# </span>**

# %% [markdown]
# **7. Общее количество этажей**

# %%
filtered_data['floors_total'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(12, 6),
    title='Распределение количества этажей')

plt.xlabel('Этажи')
plt.ylabel('Количество объявлений')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %% [markdown]
# **<span style="color: green;"> Исходя из гистограммы, можно сказать, что большая часть квартир находится в зданиях с диапазоном этажей от 5 до 10, с пиками на 5 и 9 этажах, что характерно для обычного жилья.
# </span>**

# %%
filtered_data['floors_total'].value_counts().sort_index().plot(
    kind='bar',
    figsize=(12, 6),
    title='Распределение количества этажей')
plt.xlim(10, 35)
plt.xlabel('Этажи')
plt.ylabel('Количество объявлений')
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
filtered_data['floors_total'].describe()

# %% [markdown]
# Значения в floors_total находятся в разумных пределах (2–36), скорее всего выбросов нет — фильтрация не требуется.

# %% [markdown]
# **8. Расстояние от центра города**

# %%
filtered_data['cityCenters_nearest'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')

plt.title('Распределение расстояния от центра города')
plt.xlabel('Расстояние') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Наглядно видим результат заполнения пропусков </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **<span style="color: green;"> Значительная часть квартир расположена на расстоянии от 10 000 до 18 000 метров от центра города, что находится в пределах нормы, с пиком на 15 000 метров. Однако на хвосте гистограммы наблюдаются подозрительно большие значения. Чем больше расстояние, тем более вероятно, что данный объект недвижимости находится в другом населенном пункте.
# </span>**

# %%
filtered_data['cityCenters_nearest'].plot(kind='box', showfliers=False)

# %%
filtered_data['cityCenters_nearest'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.xlim(23000, 100000)
plt.title('Распределение расстояния от центра города')
plt.xlabel('Расстояние') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
filtered_data['cityCenters_nearest'].describe()

# %% [markdown]
# **Что видно из статистики:**
#
# - Медиана: ~13 км от центра — это нормально.
#
# - 75% квартир — до ~16 км.
#
# - Максимум — почти 50 км — маловероятно для городской черты (может быть ошибка GPS или удалённый пригород).
#
#
# Сократим расстояние до 40000 метров.

# %%
filtered_data = filtered_data.query('cityCenters_nearest < 40000')

# %% [markdown]
# **9. Расстояние до ближайшего парка**

# %%
filtered_data['parks_nearest'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.title('Распределение расстояния от ближайшего парка')
plt.xlabel('Расстояние') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# **<span style="color: green;">Гистограмма показывает, что значительная часть квартир расположена вблизи парка, с пиком на расстоянии 500 метров. Также наблюдаются значительно большие значения до 3000 метров, что указывает на то, что ближайший к квартире парк находится достаточно далеко.
# </span>**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Тут стоит учитывать то, что для большинства квартир этот параметр не указан </div>

# %% [markdown]
# **10. Цена объекта**

# %%
filtered_data['last_price'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.title('Распределение цены квартиры')
plt.xlabel('Цена') 
plt.ylabel('Количество объявлений')
plt.show()

# %%
filtered_data['last_price'].plot(kind='box', showfliers=False)

# %% [markdown]
# **<span style="color: green;">Boxplot показывает, что цена на квартиры варьируется от 2.000.000 до 12.000.000 рублей, со средним значением около 4.000.000 рублей.
# </span>**

# %%
filtered_data['last_price'].describe()

# %% [markdown]
# Ставим ограничение в цене до 50.000.000 рублей.

# %%
filtered_data = filtered_data.query('last_price < 50000000')

# %% [markdown]
# **Сколько дней было размещено объявление**

# %%
filtered_data['days_exposition'].hist(bins = 200, figsize = (15, 7), color='#A7D2CB')
plt.title('Распределение дней объявления')
plt.xlabel('Дни') 
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# **<span style="color: green;">Гистограмма продаж квартир демонстрирует концентрацию в левой части, с пиковым значением в районе 100 дней. Это позволяет сделать вывод, что основная масса квартир была продана в течение первых нескольких месяцев, в то время как продажи небольшого числа объектов растянулись на несколько лет.
# </span>**

# %%
days_mean = int(filtered_data['days_exposition'].mean().round(0))
days_median = int(filtered_data['days_exposition'].median().round(0))
print(f"Среднее: {days_mean}, медиана: {days_median}")

# %%
filtered_data['days_exposition'].describe()

# %% [markdown]
# **<span style="color: blue;">Анализ длительности размещения объявлений показал, что:
# </span>**
#
# - Медианное время продажи — 94 дня, то есть половина квартир продавалась в срок до трёх месяцев.
#
#
# - Среднее значение составило 179 дней, что значительно выше медианы — это указывает на наличие отдельных случаев с очень долгим временем продажи, которые смещают среднее вверх.
#
#
# - 25% квартир были проданы за 43 дня или меньше — такие случаи можно считать быстрыми продажами.
#
#
# - 75% квартир продавались не дольше 227 дней — дольше этого срока продажи можно назвать затянувшимися.
#
#
#
#
# **<span style="color: green;">Таким образом:
# </span>**
#
#
# - **Быстрая продажа — до 43 дней,**
#
# - **Типичная — от 43 до 227 дней,**
#
# - **Необычно долгая — более 227 дней.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Значения медианы и среднего в выводе не соответствуют расчетным. При ответе на вопрос стоит обратить внимание на 25 и 75 квартили.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **Влияние факторов на общую цену**

# %%
# Рассмотрим корреляцию между ценой и такими параметрами, как общая площадь, жилая площадь, 
# площадь кухни, количество комнат, тип этажа, день недели выставления объявления, 
# месяц выставления объявления и год выставления объявления.
filtered_data[['last_price', 'total_area', 'living_area', 'kitchen_area', 'rooms', 'floor_type', 'weekday_exposition', 'month_exposition', 'year_exposition']].corr()

# %% [markdown]
# **<span style="color: green;">Из первой строки таблицы корреляции видно, что существует сильно выраженная прямая зависимость между ценой и общей площадью, а также более слабая связь между ценой и жилой площадью.Также наблюдается незначительная средняя корреляция между ценой, площадью кухни и количеством комнат. Связь с другими факторами минимальна. Построим визуальные графики для этих параметров.
# </span>**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Все библиотеки лучше импортировать в самом начале проекта, в отдельной ячейке. Если в процессе работы появилась необходимость добавить библиотеку, то ее можно дописать в эту ячейку и исполнить.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **1. Общая площадь**

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %%
sns.scatterplot(data=filtered_data, x='total_area', y='last_price')
plt.title('Зависимость цены от общей площади')
plt.xlabel('Общая площадь')
plt.ylabel('Цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">На графике наблюдается общая положительная тенденция: чем больше площадь квартиры, тем выше её цена. Основная масса объектов сосредоточена в диапазоне до 100 м² и до 10 млн рублей.
# </span>**

# %% [markdown]
# **2. Жилая площадь**

# %%
sns.scatterplot(data=filtered_data, x='living_area', y='last_price')
plt.title('Зависимость цены от жилой площади')
plt.xlabel('Жилая площадь (m²)')
plt.ylabel('Цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">График показывает положительную корреляцию между жилой площадью и ценой квартиры — в целом, с увеличением жилой площади растёт и стоимость.</span>**

# %% [markdown]
# **3. Площадь кухни**

# %%
sns.scatterplot(data=filtered_data, x='kitchen_area', y='last_price')
plt.title('Зависимость цены от площади кухни')
plt.xlabel('Площадь кухни')
plt.ylabel('Цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">Явной линейной зависимости между площадью кухни и ценой нет. Хотя можно заметить, что квартиры с большей кухней чаще стоят дороже, разброс значений очень велик. Площадь кухни оказывает слабое влияние на цену квартиры по сравнению с общей или жилой площадью. Она скорее служит дополнительной характеристикой комфорта.
# </span>**

# %% [markdown]
# **4. Количество комнат**

# %%
sns.barplot(data=filtered_data, x='rooms', y='last_price')
plt.title('Средняя цена по количеству комнат')
plt.xlabel('Количество комнат')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">Средняя цена квартиры растёт с увеличением количества комнат.
# Чем больше комнат — тем выше средняя стоимость объекта недвижимости.</span>**
#
# **Особенно заметен скачок в цене начиная с 3 комнат и выше — это может быть связано с тем, что многокомнатные квартиры чаще имеют большую площадь, расположены в более престижных районах или имеют улучшенную планировку.**
#
# **Однако стоит учитывать, что увеличение цены не строго линейное — на 5 и 6 комнат виден резкий рост.**

# %% [markdown]
# **5. День недели выставки объявления**

# %%
sns.barplot(data=filtered_data, x='weekday_exposition', y='last_price')
plt.title('Средняя цена по дню недели выставки объявления')
plt.xlabel('День недели (Пн - 0, Вс - 6)')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">Судя по barplot, день недели, в который было размещено объявление, практически не влияет на среднюю цену квартиры. Разброс значений минимален, и все столбцы находятся на примерно одинаковом уровне — около 6,5 млн рублей. Это указывает на то, что цена определяется другими факторами, а не днем публикации.
# </span>**

# %% [markdown]
# **6. Месяц выставки объявления**

# %%
sns.barplot(data=filtered_data, x='month_exposition', y='last_price')
plt.title('Средняя цена по месяцу выставки объявления')
plt.xlabel('Месяц')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">График показывает, что месяц публикации объявления практически не влияет на цену. Незначительные колебания могут быть связаны с сезонными факторами или случайными колебаниями.</span>**

# %% [markdown]
# **7. Год выставки объявления**

# %%
sns.barplot(data=filtered_data, x='year_exposition', y='last_price')
plt.title('Средняя цена по году выставки объявления')
plt.xlabel('Год')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">В этом случае наблюдается более выраженная тенденция: в 2014 году средняя цена была заметно выше, а затем произошло снижение и стабилизация на уровне ниже 8 млн рублей. Это может быть связано с экономическими изменениями, колебаниями рынка.</span>**

# %% [markdown]
# **8. Этаж**

# %%
sns.barplot(data=filtered_data, x='floor_type', y='last_price')
plt.title('Средняя цена по типу этажа')
plt.xlabel('Этаж')
plt.ylabel('Средняя цена (руб.)')
plt.grid(True)
plt.show()

# %% [markdown]
# **<span style="color: green;">Квартиры на первом этаже стоят заметно дешевле. На последнем и промежуточных этажах цены выше, особенно на последнем — вероятно, из-за лучшего вида и тишины.</span>**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# А где же визуализации и анализ зависимости цены от других параметров?</div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **10 населенных пунктов**

# %%
#Группируем по населённому пункту и считаем количество и среднюю цену за м²
pivot_table = (
    filtered_data.groupby('locality_name')
    .agg(ads_count=('locality_name', 'count'),
         mean_price_per_sqm=('price_per_meter', 'mean'))
    .sort_values(by='ads_count', ascending=False)
    
)
top10 = pivot_table.head(10)
top10

# %% [markdown]
# **<span style="color: green;">Самая высокая стоимость за м²: Санкт-Петербург — 111099.15 руб.</span>**
#
# **<span style="color: red;">Самая низкая стоимость за м²: поселок Стрельна — 88266.44 руб.</span>**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Все верно </div>

# %%
# Отбираем только квартиры, расположенные в Санкт-Петербурге и группируем их по расстоянию от центра, 
# считаем среднюю цену в каждой группе
spb_flats = filtered_data[filtered_data["locality_name"] == "Санкт-Петербург"]
price_by_distance = spb_flats.groupby("city_center_km")["last_price"].mean()

# Строим линейный график
plt.figure(figsize=(10, 6))
plt.plot(price_by_distance.index, price_by_distance.values, marker='o')
plt.title('Средняя цена квартир в зависимости от расстояния до центра (СПб)')
plt.xlabel('Расстояние до центра, км')
plt.ylabel('Средняя цена, руб.')
plt.grid(True)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Тут нагляднее будет линейный график
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# <div style="background-color: lightblue; padding: 10px;">
#     <strong>Исправлено</strong><br>
#
# </div>

# %% [markdown]
# **<span style="color: green;">Чем ближе квартира к центру Санкт-Петербурга, тем выше её средняя цена — на нуле и в пределах 1 км она достигает пика. Далее стоимость резко снижается, особенно в пределах 5–10 км, после чего стабилизируется. Это подтверждает сильную зависимость цены от расстояния до центра: центральные районы наиболее дорогие, тогда как на окраинах жильё значительно доступнее.</span>**

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# **<span style="color: green;">В рамках проекта проведена комплексная предобработка и исследовательский анализ данных о продаже квартир. Были устранены дубликаты, обработаны пропуски, скорректированы выбросы и добавлены новые признаки, такие как цена за квадратный метр, расстояние до центра и тип этажа. Это позволило глубже понять закономерности, влияющие на стоимость жилья.</span>**
#
# - **Результаты анализа показали, что наиболее сильное влияние на цену оказывают общая и жилая площадь квартиры. Чем больше площадь — тем выше цена. Также, хоть и в меньшей степени, значимыми оказались расстояние до центра города, количество комнат и этаж, на котором расположена квартира. Менее значимыми оказались такие параметры, как площадь кухни, день или месяц публикации объявления.**
#
# - **Цены на недвижимость закономерно снижаются по мере удаления от центра Санкт-Петербурга — в пределах 3 км они достигают максимума, после чего постепенно снижаются и стабилизируются. Также выявлено, что квартиры на первом этаже стоят дешевле, а на последнем — могут стоить дороже, вероятно, из-за улучшенного вида и меньшего уровня шума.**
#
# - **Скорость продаж также варьируется: медианное время продажи составляет 94 дня, что означает, что половина квартир продаётся в течение примерно трёх месяцев. Четверть квартир уходит с рынка быстрее — за 43 дня и менее, такие продажи можно считать быстрыми. Объявления, активные дольше 227 дней, можно отнести к затяжным.**
#
# - **В целом, на основе анализа можно выделить характерный образ среднестатистической квартиры: это объект площадью около 50–60 м² с жилой зоной в пределах 30 м² и кухней около 10 м². Обычно такая квартира имеет 1–2 комнаты, находится на среднем этаже дома высотой в 5–10 этажей. Высота потолков варьируется от 2.5 до 2.7 м. Располагается она на расстоянии 10–15 км от центра города и стоит в среднем 4–6,5 миллионов рублей. Срок продажи составляет примерно 1,5–3 месяца.**

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Можно дополнительно описать основные характеристики "среднестатистической" квартиры из объявления на основе результатов исследовательского анализа.
#
#
# **Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы.**
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
